# %%
import pandas as pd
import ast

# Specify the path to your CSV file
csv_file_path = 'scraped_data_reviews_food_full.csv'

# Use pandas read_csv function to read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path, encoding='utf-8')
original_rows = len(df)
print("Number of rows in the original CSV file: %d" % len(df))

# Remove duplicate rows with the same 'href', and adjust the index accordingly
df.drop_duplicates(subset='Review ID', inplace=True)
# Reset the index
df.reset_index(drop=True, inplace=True)

# Now, 'df' is a pandas DataFrame containing the data from the CSV file
# You can perform various operations and analysis on this DataFrame

# Print the first few rows of the DataFrame
print("Number of rows after removing duplicates: %d" % len(df))

print("Number of rows removed: %d" % (original_rows - len(df)))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 csv_file_path = 'scraped_data_reviews_food_full.csv'
#       7 # Use pandas read_csv function to read the CSV file into a DataFrame
# ----> 8 df = pd.read_csv(csv_file_path, encoding='utf-8')
#       9 original_rows = len(df)
#      10 print("Number of rows in the original CSV file: %d" % len(df))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'scraped_data_reviews_food_full.csv'

# %%
original_rows = len(df)
print("Number of rows in the original CSV file: %d" % len(df))

#limits the number of reviews per place to 5
df['href of Place'] = df.groupby('href of Place').head(5)
#drops all rows with blanks (aka the duplicate rows above 5)
df.dropna(subset=['href of Place'], inplace=True)
df.reset_index(drop=True, inplace=True)

print("Number of rows after removing duplicates: %d" % len(df))
print("Number of rows removed: %d" % (original_rows - len(df)))

print("Categories and their counts:")
print(df['href of Place'].value_counts())
# Out:
# Number of rows in the original CSV file: 63247
# Number of rows after removing duplicates: 63128
# Number of rows removed: 119
# Categories and their counts:
# https://www.google.com/maps/place/Sintia%27s+Indonesian+Food/data=!4m7!3m6!1s0x31da1a11943bd381:0x7f162264ca77e695!8m2!3d1.3160429!4d103.8054961!16s%2Fg%2F11j4t63y4b!19sChIJgdM7lBEa2jERleZ3ymQiFn8?authuser=0&hl=en&rclk=1              5
# https://www.google.com/maps/place/Guzman+y+Gomez+-+ION+Orchard/data=!4m7!3m6!1s0x31da19d85724d9b9:0xad0cbed308148522!8m2!3d1.3041664!4d103.8317794!16s%2Fg%2F11s94ljrgz!19sChIJudkkV9gZ2jERIoUUCNO-DK0?authuser=0&hl=en&rclk=1            5
# https://www.google.com/maps/place/%E4%B8%8D%E9%A5%BF%E4%B8%8D%E5%9D%90/data=!4m7!3m6!1s0x31da3dfe8267b769:0xea52f86208823ba5!8m2!3d1.3933497!4d103.9176661!16s%2Fg%2F11kk7mlqm_!19sChIJabdngv492jERpTuCCGL4Uuo?authuser=0&hl=en&rclk=1    5
# https://www.google.com/maps/place/Subway/data=!4m7!3m6!1s0x31da3c8a1d5b365b:0x4d75059b9004bdb4!8m2!3d1.3603912!4d103.989642!16s%2Fg%2F11h9_p67_x!19sChIJWzZbHYo82jERtL0EkJsFdU0?authuser=0&hl=en&rclk=1                                   5
# https://www.google.com/maps/place/Indian+Cusine/data=!4m7!3m6!1s0x31da17d7d390bcbd:0x15117af2b5f1807e!8m2!3d1.3940251!4d103.9132746!16s%2Fg%2F11h6lzrlj7!19sChIJvbyQ09cX2jERfoDxtfJ6ERU?authuser=0&hl=en&rclk=1                           5
#                                                                                                                                                                                                                                          ..
# https://www.google.com/maps/place/ANG+MO+KIP+SOPN+LI+ROJAK/data=!4m7!3m6!1s0x31da194778fcd4bd:0x74fa56b22bc65a86!8m2!3d1.2841977!4d103.8425488!16s%2Fg%2F11kby9d7pd!19sChIJvdT8eEcZ2jERhlrGK7JW-nQ?authuser=0&hl=en&rclk=1                1
# https://www.google.com/maps/place/Herbal+Soup+%E4%BD%B3%E5%91%B3/data=!4m7!3m6!1s0x31da174ed9891a03:0xc39ee34b11b84dde!8m2!3d1.3329179!4d103.8471827!16s%2Fg%2F11h07ym0ts!19sChIJAxqJ2U4X2jER3k24EUvjnsM?authuser=0&hl=en&rclk=1          1
# https://www.google.com/maps/place/Chang+Cheng+-+531+Ang+Mo+Kio+Avenue+10/data=!4m7!3m6!1s0x31da16ef881f9b51:0xc9a9e7e24fd305be!8m2!3d1.373356!4d103.854322!16s%2Fg%2F11b6dpm7_7!19sChIJUZsfiO8W2jERvgXTT-Lnqck?authuser=0&hl=en&rclk=1    1
# https://www.google.com/maps/place/My+Mums+Kitchen+Pte+Ltd/data=!4m7!3m6!1s0x31da07b84b027975:0x64a87c02d5769db9!8m2!3d1.3187464!4d103.6290285!16s%2Fg%2F11q3nfrj8n!19sChIJdXkCS7gH2jERuZ121QJ8qGQ?authuser=0&hl=en&rclk=1                 1
# https://www.google.com/maps/place/Q.W.+%28S%29+Pte.+Ltd./data=!4m7!3m6!1s0x31da1a633ca20e37:0x773d18f3e8e06761!8m2!3d1.316644!4d103.7789729!16s%2Fg%2F11c1wslps7!19sChIJNw6iPGMa2jERYWfg6PMYPXc?authuser=0&hl=en&rclk=1                   1
# Name: href of Place, Length: 13686, dtype: int64

# %%
import pandas as pd
import ast

# Assuming df is your DataFrame and it already exists

# Safely convert the string representation of list of strings into a list of strings
df['Metadata'] = df['Metadata'].apply(ast.literal_eval)

# Create two new columns "Service Rating" and "Service Type"
df['Service Rating'] = None
df['Service Type'] = None

# Function to process and return the correct value based on the input
def process_value(value, key):
    if "$" in value or key == "Price per person":
        value = value.replace("$", "").replace("RM ", "")
        if "+" in value:
            value = value.replace("+", "")
            return float(value)*1.5
        if "–" in value:
            parts = value.split("–")
            return sum(float(part) for part in parts) / len(parts)
        return float(value)
    try:
        return int(value)
    except ValueError:
        return value

def rating_or_type(value):
    # if integer, then it's a rating
    try:
        int(value)
        return "Service Rating"
    except ValueError:
        return "Service Type"

# Iterate over each row and update the DataFrame with new columns for each key-value pair
for index, metadata_list in enumerate(df['Metadata']):
    for item in metadata_list:
        try:
            key, value = item.split(": ", 1)
            if key == "Service":
                key = rating_or_type(value)
            df.at[index, key] = process_value(value, key)
        except ValueError:
            # print(f"Key has no value: {item}")
            pass

# Drop the columns in which there is less than 20% of non-null values
df.dropna(thresh=len(df) * 0.2, axis=1, inplace=True)


# Drop the original 'Metadata' column
df.drop(columns=['Metadata'], inplace=True)

df
# Out:
#                                            href of Place  \
# 0      https://www.google.com/maps/place/One+More+Bow...
# 1      https://www.google.com/maps/place/One+More+Bow...
# 2      https://www.google.com/maps/place/Lian+Kee/dat...
# 3      https://www.google.com/maps/place/One+More+Bow...
# 4      https://www.google.com/maps/place/One+More+Bow...
# ...                                                  ...
# 63123  https://www.google.com/maps/place/Wok+Express+...
# 63124  https://www.google.com/maps/place/Wok+Express+...
# 63125  https://www.google.com/maps/place/Wok+Express+...
# 63126  https://www.google.com/maps/place/Wok+Express+...
# 63127  https://www.google.com/maps/place/Wok+Express+...
#
#                                   Review ID  Relavancy Ranking  \
# 0       ChZDSUhNMG9nS0VJQ0FnSURGXy1peFZREAE                  1
# 1      ChdDSUhNMG9nS0VJQ0FnSUQyME5YZnJRRRAB                  2
# 2      ChdDSUhNMG9nS0VJQ0FnSUNacWFPZnp3RRAB                  1
# 3      ChdDSUhNMG9nS0VJQ0FnSUQtckp2UDd3RRAB                  3
# 4      ChdDSUhNMG9nS0VJQ0FnSURPbDhqTC1nRRAB                  4
# ...                                     ...                ...
# 63123  ChdDSUhNMG9nS0VJQ0FnSURSaDllMXJnRRAB                  1
# 63124   ChZDSUhNMG9nS0VJQ0FnSUN4NE5MT0FnEAE                  2
# 63125   ChZDSUhNMG9nS0VJQ0FnSUNaMUx1SFF3EAE                  3
# 63126  ChdDSUhNMG9nS0VJQ0FnSUNla2JPbTRRRRAB                  4
# 63127  ChdDSUhNMG9nS0VJQ0FnSURleXA2NDJRRRAB                  5
#
#                                            Reviewer href  \
# 0      https://www.google.com/maps/contrib/1157070012...
# 1      https://www.google.com/maps/contrib/1143455552...
# 2      https://www.google.com/maps/contrib/1043278646...
# 3      https://www.google.com/maps/contrib/1127702228...
# 4      https://www.google.com/maps/contrib/1118800275...
# ...                                                  ...
# 63123  https://www.google.com/maps/contrib/1074762720...
# 63124  https://www.google.com/maps/contrib/1090930684...
# 63125  https://www.google.com/maps/contrib/1020535585...
# 63126  https://www.google.com/maps/contrib/1030788709...
# 63127  https://www.google.com/maps/contrib/1074449045...
#
#               Reviewer Name  Local Guide Total Reviews Total Photos  \
# 0                   Yi Ling         True           524         3850
# 1                      CK C         True          1863         5617
# 2               Daphne Seow         True           360         4251
# 3      William Amedeo Chong         True            45           51
# 4                      Kuan         True            85           59
# ...                     ...          ...           ...          ...
# 63123          Nicholas Tan         True            83          208
# 63124            Elaine Lee        False             4           13
# 63125           Adriana Zul        False         Local           17
# 63126                  Yang         True           852        16757
# 63127                    sy        False             2            1
#
#        Star Rating                        Date  \
# 0                4  2023-12-02 10:01:11.963467
# 1                5  2023-02-02 10:01:12.483552
# 2                5  2023-12-02 10:01:12.730551
# 3                5  2023-02-02 10:01:13.066097
# 4                4  2023-02-02 10:01:13.779937
# ...            ...                         ...
# 63123            4  2023-06-03 00:20:39.441882
# 63124            1  2023-06-03 00:20:39.943853
# 63125            4  2023-10-03 00:20:40.525909
# 63126            4  2023-02-03 00:20:40.955822
# 63127            1  2023-02-03 00:20:41.307702
#
#                                                   Review  Likes  \
# 0      Would say it's a relatively good bowl of dry m...      0
# 1      Dry Mee Hoon Kueh was very tasty and generous ...      3
# 2      One of my favourite soup noodles places! Love ...      1
# 3      This has to be the no.1 dry mee hoon kueh I ha...      1
# 4      Mee hoon Kueh texture is good. Q-Q and not sog...      0
# ...                                                  ...    ...
# 63123  The food is pretty nice and average filling fo...      0
# 63124  Ordered take out on 8 May 2023. After eating h...      2
# 63125  1 meat + 4 other toppings costed me $7. ok to ...      1
# 63126  Wok Hei strong here.\nFried rice is nice.\nMay...      1
# 63127  Woman taking my order was rude it's ok if u do...      0
#
#                                       Review Images href Service Rating  \
# 0      ['https://lh5.googleusercontent.com/p/AF1QipNd...              3
# 1      ['https://lh5.googleusercontent.com/p/AF1QipPI...           None
# 2      ['https://lh5.googleusercontent.com/p/AF1QipOD...              5
# 3      ['https://lh5.googleusercontent.com/p/AF1QipNW...              5
# 4      ['https://lh5.googleusercontent.com/p/AF1QipNG...           None
# ...                                                  ...            ...
# 63123  ['https://lh5.googleusercontent.com/p/AF1QipPo...              4
# 63124  ['https://lh5.googleusercontent.com/p/AF1QipMD...           None
# 63125                                                 []              4
# 63126  ['https://lh5.googleusercontent.com/p/AF1QipOX...           None
# 63127  ['https://lh5.googleusercontent.com/p/AF1QipMZ...           None
#
#       Service Type  Food  Atmosphere  Meal type  Price per person  \
# 0             None   3.0         4.0        NaN               NaN
# 1             None   NaN         NaN        NaN               NaN
# 2          Dine in   5.0         5.0  Breakfast               5.5
# 3             None   5.0         4.0        NaN               NaN
# 4          Dine in   NaN         NaN      Lunch               NaN
# ...            ...   ...         ...        ...               ...
# 63123         None   4.0         3.0        NaN               NaN
# 63124     Take out   NaN         NaN     Dinner               5.5
# 63125     Take out   4.0         3.0      Lunch               5.5
# 63126     Take out   NaN         NaN      Lunch               NaN
# 63127         None   NaN         NaN        NaN               NaN
#
#                                       Recommended dishes
# 0                                                    NaN
# 1                                                    NaN
# 2      Fishball Noodle, Fishball Soup, Meatball Soup,...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 63123                                                NaN
# 63124                                                NaN
# 63125  Egg Fried Rice, Sous Vide Egg, Vegetable Toppings
# 63126                                                NaN
# 63127                                                NaN
#
# [63128 rows x 20 columns]

# %%
# Process the 'Date' column to keep only the date part
df['Date'] = pd.to_datetime(df['Date']).dt.date

# Display the date part of df
df['Date']
# Out:
# 0        2023-12-02
# 1        2023-02-02
# 2        2023-12-02
# 3        2023-02-02
# 4        2023-02-02
#             ...
# 63123    2023-06-03
# 63124    2023-06-03
# 63125    2023-10-03
# 63126    2023-02-03
# 63127    2023-02-03
# Name: Date, Length: 63128, dtype: object

# %%
# Write to a new CSV file
df.to_csv('scraped_data_reviews_food_processed.csv', encoding='utf-8-sig',index=False)
